# %%
corpus="Hello Welcome! to PC NLP Notebook.Please do watch the entire course! to become expert in NLP."

# %%
##Tokenization 
##Sentence from paragraphs
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

# Download required NLTK data (run this once)
nltk.download('punkt_tab')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/piyushajitchavan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/piyushajitchavan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/piyushajitchavan/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/piyushajitchavan/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/piyushajitchavan/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
documents=sent_tokenize(corpus)
print(documents)
# Out:
# ['Hello Welcome!', 'to PC NLP Notebook.Please do watch the entire course!', 'to become expert in NLP.']

# %%
words=word_tokenize(corpus)
print(words)
# Out:
# ['Hello', 'Welcome', '!', 'to', 'PC', 'NLP', 'Notebook.Please', 'do', 'watch', 'the', 'entire', 'course', '!', 'to', 'become', 'expert', 'in', 'NLP', '.']
