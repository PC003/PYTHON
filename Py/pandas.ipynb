# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('ai_models_performance.csv')

# %%
df.head()
# Out:
#                          Model Context Window    Creator Intelligence Index  \
# 0              GPT-5.2 (xhigh)           400k     OpenAI                 51
# 1              Claude Opus 4.5           200k  Anthropic                 49
# 2  Gemini 3 Pro Preview (high)             1m     Google                 48
# 3               GPT-5.1 (high)           400k     OpenAI                 47
# 4               Gemini 3 Flash             1m     Google                 46
#
#   Price (Blended USD/1M Tokens)  Speed(median token/s)  \
# 0                        $4.81                     100
# 1                       $10.00                      79
# 2                        $4.50                     128
# 3                        $3.44                     127
# 4                        $1.13                     224
#
#    Latency (First Answer Chunk /s)
# 0                            44.29
# 1                             1.70
# 2                            32.19
# ...

# %%
grp_by_creator=df.groupby('Creator')
grp_by_creator

# %%
d=np.random.randint(1,10,size=(4,6))
x=pd.DataFrame(d,columns=['A','B','C','D','E','F'],index=['X','Y','Z','W'])
x
# Out:
#    A  B  C  D  E  F
# X  2  4  2  8  3  5
# Y  4  1  6  7  6  2
# Z  6  4  7  6  5  8
# W  5  5  2  9  7  9

# %%
x['AB']=x['A']*x['B']
x
# Out:
#    A  B  C  D  E  F  AB
# X  2  4  2  8  3  5   8
# Y  4  1  6  7  6  2   4
# Z  6  4  7  6  5  8  24
# W  5  5  2  9  7  9  25

# %%
row_sum=x.sum(axis=1)
col_sum=x.sum(axis=0)
print(row_sum)
print(col_sum)
# Out:
# X    32
# Y    30
# Z    60
# W    62
# dtype: int64
# A     17
# B     14
# C     17
# D     30
# E     21
# F     24
# AB    61
# dtype: int64
