# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('maindata.csv')

# %%
data.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
data.describe()
# Out:
#            Value       Sales
# count  47.000000   46.000000
# mean   51.744681  557.130435
# std    29.050532  274.598584
# min     2.000000  108.000000
# 25%    27.500000  339.000000
# 50%    54.000000  591.500000
# 75%    70.000000  767.500000
# max    99.000000  992.000000

# %%
data['filled_na_value']=data['Value'].fillna(data['Value'].mean())
data.head()
# Out:
#          Date Category  Value   Product  Sales Region  filled_na_value  \
# 0  2023-01-01        A   28.0  Product1  754.0   East             28.0
# 1  2023-01-02        B   39.0  Product3  110.0  North             39.0
# 2  2023-01-03        C   32.0  Product2  398.0   East             32.0
# 3  2023-01-04        B    8.0  Product1  522.0   East              8.0
# 4  2023-01-05        B   26.0  Product3  869.0  North             26.0
#
#    new_value
# 0       56.0
# 1       78.0
# 2       64.0
# 3       16.0
# 4       52.0

# %%
data['new_value']=data['filled_na_value'].apply(lambda x:x*2)
data.head()
# Out:
#          Date Category  Value   Product  Sales Region  filled_na_value  \
# 0  2023-01-01        A   28.0  Product1  754.0   East             28.0
# 1  2023-01-02        B   39.0  Product3  110.0  North             39.0
# 2  2023-01-03        C   32.0  Product2  398.0   East             32.0
# 3  2023-01-04        B    8.0  Product1  522.0   East              8.0
# 4  2023-01-05        B   26.0  Product3  869.0  North             26.0
#
#    new_value
# 0       56.0
# 1       78.0
# 2       64.0
# 3       16.0
# 4       52.0

# %%
df1=pd.DataFrame({
    "key":['A','B','C'],
    "Value1":[1,2,3]
})

df2=pd.DataFrame({
    "key":['A','B','D'],
    "Value2":[5,6,4]
})

# %%
pd.merge(df1,df2,on="key",how="inner")
# Out:
#   key  Value1  Value2
# 0   A       1       5
# 1   B       2       6

# %%
pd.merge(df1,df2,on="key",how="outer")
# Out:
#   key  Value1  Value2
# 0   A     1.0     5.0
# 1   B     2.0     6.0
# 2   C     3.0     NaN
# 3   D     NaN     4.0

# %%
pd.merge(df1,df2,on="key",how="left")
# Out:
#   key  Value1  Value2
# 0   A       1     5.0
# 1   B       2     6.0
# 2   C       3     NaN

# %%
pd.merge(df1,df2,on="key",how="right")
# Out:
#   key  Value1  Value2
# 0   A     1.0       5
# 1   B     2.0       6
# 2   D     NaN       4

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 1.1 MB/s  0:00:07 eta 0:00:010m
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.8 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 2.8 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...

# %%
import matplotlib.pyplot as plt

data=[35, 40, 42, 45, 50, 55, 60, 65, 70, 75, 80, 85]
plt.hist(data,bins=10,color="orange",edgecolor="black")
# Out:
# (array([1., 2., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([35., 40., 45., 50., 55., 60., 65., 70., 75., 80., 85.]),
#  <BarContainer object of 10 artists>)

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(y='total_bill',x='total_bill',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
corr=tips[['total_bill','tip','size']].corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >
